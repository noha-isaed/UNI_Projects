# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
 
# %matplotlib inline

# %%
df_player = pd.read_csv('epldata_final.csv')
df_player
# Out:
#                         name         club  age position  position_cat  \
# 0             Alexis Sanchez      Arsenal   28       LW             1
# 1                 Mesut Ozil      Arsenal   28       AM             1
# 2                  Petr Cech      Arsenal   35       GK             4
# 3               Theo Walcott      Arsenal   28       RW             1
# 4          Laurent Koscielny      Arsenal   31       CB             3
# 5            Hector Bellerin      Arsenal   22       RB             3
# 6             Olivier Giroud      Arsenal   30       CF             1
# 7              Nacho Monreal      Arsenal   31       LB             3
# 8           Shkodran Mustafi      Arsenal   25       CB             3
# 9                 Alex Iwobi      Arsenal   21       LW             1
# 10              Granit Xhaka      Arsenal   24       DM             2
# 11   Alex Oxlade-Chamberlain      Arsenal   23       RM             2
# ...

# %%
df_player['market_value']
# Out:
# 0      65.00
# 1      50.00
# 2       7.00
# 3      20.00
# 4      22.00
# 5      30.00
# 6      22.00
# 7      13.00
# 8      30.00
# 9      10.00
# 10     35.00
# 11     22.00
# 12     18.00
# 13     35.00
# 14     15.00
# 15     13.00
# 16     10.00
# 17     12.00
# 18     15.00
# 19      7.00
# 20     10.00
# 21     15.00
# 22      1.00
# 23      7.00
# 24      5.00
# 25      6.00
# 26     15.00
# 27     40.00
# 28      8.00
# 29      5.00
#        ...
# 431    10.00
# 432     4.00
# 433     3.00
# 434     2.50
# 435     1.50
# 436     0.25
# 437     1.50
# 438     1.00
# 439     8.00
# 440    15.00
# 441    18.00
# 442    10.00
# 443     7.00
# 444    18.00
# 445    12.00
# 446     7.00
# 447     2.50
# 448     2.00
# 449    10.00
# 450     8.00
# 451    12.00
# 452     9.00
# 453    12.00
# 454     9.00
# 455     7.00
# 456     5.00
# 457     7.00
# 458     4.50
# 459     1.00
# 460    10.00
# Name: market_value, Length: 461, dtype: float64

# %%
df_most=df_player.sort_values('market_value' , ascending=False)
df_most.head(6)
# Out:
#                 name               club  age position  position_cat  \
# 92       Eden Hazard            Chelsea   26       LW             1
# 263       Paul Pogba  Manchester+United   24       CM             2
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 240  Kevin De Bruyne    Manchester+City   26       AM             1
# 241    Sergio Aguero    Manchester+City   29       CF             1
# 377       Harry Kane          Tottenham   23       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 92           75.0        4220       10.5   2.30%         224     2.0
# 263          75.0        7435        8.0  19.50%         115     2.0
# 0            65.0        4329       12.0  17.10%         264     3.0
# 240          65.0        2252       10.0  17.50%         199     2.0
# 241          65.0        4046       11.5   9.70%         175     3.0
# 377          60.0        4161       12.5  35.10%         224     1.0
#
# ...

# %%
df_r=df_player.sort_values('page_views' , ascending=False)
df_r.head()
# Out:
#              name               club  age position  position_cat  \
# 143  Wayne Rooney            Everton   31       SS             1
# 263    Paul Pogba  Manchester+United   24       CM             2
# 376     Dele Alli          Tottenham   21       CM             2
# 93    Diego Costa            Chelsea   28       CF             1
# 1      Mesut Ozil            Arsenal   28       AM             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 143          15.0        7664        7.5  20.90%          76     1.0
# 263          75.0        7435        8.0  19.50%         115     2.0
# 376          45.0        4626        9.5  38.60%         225     1.0
# 93           50.0        4454       10.0   3.00%         196     2.0
# 1            50.0        4395        9.5   5.60%         167     2.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 143     England            0        4        7         0            0
# ...

# %%
df_most2 = df_most[['name' ,'market_value']]

# %%
to = df_most2.plot.bar(x='name' , y='market_value' , rot=0)

# %%
df_most1 = df_player[['name' ,'market_value']]

# %%
t = df_most1.plot.bar(x='name' , y='market_value' , rot=0)

# %%
df_t=df_player.sort_values('market_value' , ascending=False)
df_t
# Out:
#                      name               club  age position  position_cat  \
# 92            Eden Hazard            Chelsea   26       LW             1
# 263            Paul Pogba  Manchester+United   24       CM             2
# 0          Alexis Sanchez            Arsenal   28       LW             1
# 240       Kevin De Bruyne    Manchester+City   26       AM             1
# 241         Sergio Aguero    Manchester+City   29       CF             1
# 377            Harry Kane          Tottenham   23       CF             1
# 93            Diego Costa            Chelsea   28       CF             1
# 104        N%27Golo Kante            Chelsea   26       DM             2
# 1              Mesut Ozil            Arsenal   28       AM             1
# 260         Romelu Lukaku  Manchester+United   24       CF             1
# 376             Dele Alli          Tottenham   21       CM             2
# 242       Raheem Sterling    Manchester+City   22       LW             1
# ...

# %%
df_re=df_t[df_t['market_value']<65]
df_re
# Out:
#                      name               club  age position  position_cat  \
# 377            Harry Kane          Tottenham   23       CF             1
# 93            Diego Costa            Chelsea   28       CF             1
# 104        N%27Golo Kante            Chelsea   26       DM             2
# 1              Mesut Ozil            Arsenal   28       AM             1
# 260         Romelu Lukaku  Manchester+United   24       CF             1
# 376             Dele Alli          Tottenham   21       CM             2
# 242       Raheem Sterling    Manchester+City   22       LW             1
# 214     Philippe Coutinho          Liverpool   25       AM             1
# 261          David de Gea  Manchester+United   26       GK             4
# 378     Christian Eriksen          Tottenham   25       AM             1
# 259        Bernardo Silva    Manchester+City   22       RW             1
# 215            Sadio Mane          Liverpool   25       LW             1
# ...

# %%
df_h = df_re[['name' ,'market_value']]

# %%
d = df_h.plot.bar(x='name' , y='market_value' , rot=0)

# %%
df_top=df_most.head()
ah = df_top.plot.bar(x='name', y='market_value', rot=0)

# %%
df_top2=df_player.head()
ah = df_top2.plot.bar(x='name', y='market_value', rot=0)

# %%
ax = df_r.plot.bar(x='name', y='page_views', rot=0)

# %%
df_top2=df_r.head()
ax = df_top2.plot.bar(x='name', y='page_views', rot=0)

# %%
g = df_player.plot.scatter(x='age',y='fpl_value', c='DarkBlue')

# %%
#We see here that the FPL VALUTION concentrated in the period from 20 to 30

# %%
g = df_player.plot.scatter(x='position_cat',y='fpl_value', c='DarkBlue')

# %%
g = df_player.plot.scatter(x='market_value',y='fpl_value', c='DarkBlue')

# %%
g = df_player.plot.scatter(x='age',y='market_value', c='DarkBlue')

# %%
df_j=df_player[df_player['club_id'] == 1]
df_j["position_cat"].value_counts()
# Out:
# 3    10
# 1     8
# 2     7
# 4     3
# Name: position_cat, dtype: int64

# %%
df_j2=df_player[df_player['club_id'] == 2]
df_j2["position_cat"].value_counts()
# Out:
# 1    10
# 3     7
# 2     4
# 4     3
# Name: position_cat, dtype: int64

# %%
df_j3=df_player[df_player['club_id'] == 3]
df_j3["position_cat"].value_counts()
# Out:
# 3    7
# 1    7
# 2    6
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j4=df_player[df_player['club_id'] == 4]
df_j4["position_cat"].value_counts()
# Out:
# 2    8
# 3    5
# 1    4
# 4    1
# Name: position_cat, dtype: int64

# %%
df_j5=df_player[df_player['club_id'] == 5]
df_j5["position_cat"].value_counts()
# Out:
# 3    7
# 1    6
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j6=df_player[df_player['club_id'] == 6]
df_j6["position_cat"].value_counts()
# Out:
# 3    8
# 1    7
# 2    4
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j7=df_player[df_player['club_id'] == 7]
df_j7["position_cat"].value_counts()
# Out:
# 3    10
# 1     9
# 2     6
# 4     3
# Name: position_cat, dtype: int64

# %%
df_j8=df_player[df_player['club_id'] == 8]
df_j8["position_cat"].value_counts()
# Out:
# 1    11
# 3    10
# 2     5
# 4     2
# Name: position_cat, dtype: int64

# %%
df_j9=df_player[df_player['club_id'] == 9]
df_j9["position_cat"].value_counts()
# Out:
# 3    8
# 2    7
# 1    7
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j10=df_player[df_player['club_id'] == 10]
df_j10["position_cat"].value_counts()
# Out:
# 1    11
# 3     8
# 2     6
# 4     2
# Name: position_cat, dtype: int64

# %%
df_j11=df_player[df_player['club_id'] == 11]
df_j11["position_cat"].value_counts()
# Out:
# 1    8
# 3    5
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j12=df_player[df_player['club_id'] == 12]
df_j12["position_cat"].value_counts()
# Out:
# 3    10
# 2     6
# 1     6
# 4     3
# Name: position_cat, dtype: int64

# %%
df_j13=df_player[df_player['club_id'] == 13]
df_j13["position_cat"].value_counts()
# Out:
# 3    8
# 1    7
# 2    4
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j14=df_player[df_player['club_id'] == 14]
df_j14["position_cat"].value_counts()
# Out:
# 3    8
# 2    7
# 1    7
# 4    1
# Name: position_cat, dtype: int64

# %%
df_j15=df_player[df_player['club_id'] == 15]
df_j15["position_cat"].value_counts()
# Out:
# 1    8
# 3    7
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j16=df_player[df_player['club_id'] == 16]
df_j16["position_cat"].value_counts()
# Out:
# 1    10
# 3     7
# 2     6
# 4     2
# Name: position_cat, dtype: int64

# %%
df_j17=df_player[df_player['club_id'] == 17]
df_j17["position_cat"].value_counts()
# Out:
# 3    6
# 2    6
# 1    6
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j18=df_player[df_player['club_id'] == 18]
df_j18["position_cat"].value_counts()
# Out:
# 3    9
# 1    7
# 2    6
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j19=df_player[df_player['club_id'] == 19]
df_j19["position_cat"].value_counts()
# Out:
# 1    7
# 3    5
# 2    5
# 4    2
# Name: position_cat, dtype: int64

# %%
df_j20=df_player[df_player['club_id'] == 20]
df_j20["position_cat"].value_counts()
# Out:
# 3    8
# 1    8
# 2    4
# 4    2
# Name: position_cat, dtype: int64

# %%
#The Team with the Most stock on Attackers:
#Liverpool-11 Hudersfeild-11

#The Team with the Most stock on Midfielders :
#*Burnley- 8

#The Team with the Most stock on Defenders:
#Arsnel-10 Everton-10 *Man. United-10

#The Team with the Most stock on Goalkeepers:
#Arsnel-3 Bournemouth-3 Everton-3 Man.United-3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# %matplotlib inline

# %%
df_swing = pd.read_csv('2008_swing_states.csv')
df_swing[['pct_rep','pct_dem']]
# Out:
#       pct_rep  pct_dem
# 0       73.60    25.80
# 1       75.30    23.80
# 2       50.40    49.00
# 3       72.40    26.60
# 4       84.00    14.50
# 5       25.70    74.10
# 6       56.50    43.10
# 7       65.70    33.20
# 8       53.90    45.50
# 9       74.90    23.70
# 10      78.50    20.70
# 11      53.50    46.10
# 12      55.60    44.00
# 13      73.10    25.80
# 14      80.40    18.00
# 15      74.10    25.20
# 16      59.30    39.10
# 17      50.00    49.40
# 18      58.40    40.90
# 19      78.80    20.50
# 20      68.70    30.80
# 21      81.90    16.60
# 22      71.90    27.30
# 23      32.60    67.10
# 24      74.80    23.60
# 25      75.10    24.20
# 26      63.90    35.40
# 27      68.40    30.20
# 28      73.90    25.10
# 29      68.80    29.70
# ...       ...      ...
# 3124    78.41    19.50
# 3125    72.04    25.22
# 3126    73.16    24.29
# 3127    77.54    20.39
# 3128    74.21    22.64
# 3129    72.67    24.64
# 3130    70.08    28.00
# 3131    66.32    31.91
# ...

# %%
 df_swing.pct_rep.mean()
# Out:
# 53.636442612555484

# %%
df_swing.pct_dem.mean()
# Out:
# 38.33798351299945

# %%
df_Avg1=df_swing[(df_swing['pct_rep']>40) & (df_swing['pct_rep']<53) ]
df_Avg1
# Out:
#       year state                                       county   fips  \
# 2     2008    AL                               Barbour County   1005
# 17    2008    AL                               Conecuh County   1035
# 36    2008    AL                             Jefferson County   1073
# 45    2008    AL                               Marengo County   1091
# 50    2008    AL                            Montgomery County   1101
# 56    2008    AL                               Russell County   1113
# 69    2008    AZ                              Coconino County   4005
# 77    2008    AZ                                  Pima County   4019
# 90    2008    AR                                Chicot County   5017
# 91    2008    AR                                 Clark County   5019
# 99    2008    AR                            Crittenden County   5035
# 102   2008    AR                                 Desha County   5041
# 128   2008    AR                           Mississippi County   5093
# ...

# %%
df_Avg2=df_swing[(df_swing['pct_dem']>38) & (df_swing['pct_dem']<50)]
df_Avg2
# Out:
#       year state                                       county   fips  \
# 2     2008    AL                               Barbour County   1005
# 6     2008    AL                                Butler County   1013
# 8     2008    AL                              Chambers County   1017
# 11    2008    AL                               Choctaw County   1023
# 12    2008    AL                                Clarke County   1025
# 16    2008    AL                               Colbert County   1033
# 17    2008    AL                               Conecuh County   1035
# 18    2008    AL                                 Coosa County   1037
# 40    2008    AL                                   Lee County   1081
# 44    2008    AL                               Madison County   1089
# 48    2008    AL                                Mobile County   1097
# 49    2008    AL                                Monroe County   1099
# 53    2008    AL                               Pickens County   1107
# ...

# %%
df_Avg2["state"].value_counts()
# Out:
# IN    62
# VA    57
# MN    53
# IL    52
# MO    49
# IA    47
# KY    44
# OH    43
# MI    41
# NC    39
# PA    34
# GA    31
# SD    30
# WV    30
# NY    28
# TN    26
# TX    25
# FL    25
# MS    22
# CA    20
# SC    19
# AR    18
# ND    17
# LA    16
# AL    16
# WI    15
# AK    15
# CO    14
# WA    14
# MT    14
# MD    13
# KS    12
# OR    12
# NE    11
# OK     8
# ID     7
# NJ     7
# AZ     6
# NV     6
# NM     6
# UT     3
# ME     2
# DE     1
# WY     1
# Name: state, dtype: int64

# %%
df_states=df_Avg2[df_Avg2.state == 'AL']
df_states.append(df_Avg2[df_Avg2.state == 'AR'])
df_states.append(df_Avg2[df_Avg2.state == 'CA'])

df_states.append(df_Avg1[df_Avg1.state == 'AL']) 
df_states.append(df_Avg1[df_Avg1.state == 'AR'])
df_states.append(df_Avg1[df_Avg1.state == 'CA'])
# Out:
#      year state                  county  fips  vote_rep  vote_dem  vote_oth  \
# 2    2008    AL          Barbour County  1005      5866      5697        67
# 6    2008    AL           Butler County  1013      5485      4188        36
# 8    2008    AL         Chambers County  1017      8067      6799        90
# 11   2008    AL          Choctaw County  1023      4223      3636        35
# 12   2008    AL           Clarke County  1025      7466      5914        55
# 16   2008    AL          Colbert County  1033     14739      9703       401
# 17   2008    AL          Conecuh County  1035      3470      3429        44
# 18   2008    AL            Coosa County  1037      3248      2273        42
# 40   2008    AL              Lee County  1081     32230     21498       597
# 44   2008    AL          Madison County  1089     86965     64117      1817
# 48   2008    AL           Mobile County  1097     98049     82181      1194
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
df_swing = pd.read_csv('iris-data.csv')

# %%
df_swing
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %%
df_swing.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#     iris_class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df_swing.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
df=df_swing[df_swing['iris_class']== 'Iris-versicolor']
df
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 50            7.000             3.2              4.7             1.4
# 51            6.400             3.2              4.5             1.5
# 52            6.900             3.1              4.9             1.5
# 53            5.500             2.3              4.0             1.3
# 54            6.500             2.8              4.6             1.5
# 55            5.700             2.8              4.5             1.3
# 56            6.300             3.3              4.7             1.6
# 57            4.900             2.4              3.3             1.0
# 58            6.600             2.9              4.6             1.3
# 59            5.200             2.7              3.9             1.4
# 60            5.000             2.0              3.5             1.0
# 61            5.900             3.0              4.2             1.5
# 62            6.000             2.2              4.0             1.0
# ...

# %%
data1 = np.array(df[['petal_length_cm']] )
data2 = np.array(df[['petal_width_cm']]  )

# %%
data1
data2
# Out:
# array([[1.4],
#        [1.5],
#        [1.5],
#        [1.3],
#        [1.5],
#        [1.3],
#        [1.6],
#        [1. ],
#        [1.3],
#        [1.4],
#        [1. ],
#        [1.5],
#        [1. ],
#        [1.4],
#        [1.3],
#        [1.4],
#        [1.5],
#        [1. ],
#        [1.5],
#        [1.1],
#        [1.8],
#        [1.3],
#        [1.5],
#        [1.2],
#        [1.3],
#        [1.4],
#        [1.4],
#        [1.7],
#        [1.5],
#        [1. ],
#        [1.1],
#        [1. ],
#        [1.2],
#        [1.6],
#        [1.5],
#        [1.6],
#        [1.5],
#        [1.3],
#        [1.3],
#        [1.3],
#        [1.2],
#        [1.4],
#        [1.2],
#        [1. ],
#        [1.3],
#        [1.2],
#        [1.3],
#        [1.3],
#        [1.1],
#        [1.3]])

# %%
df.loc[:,"petal_length_cm"].std()
# Out:
# 0.46991097723995806

# %%
df.loc[: ,"petal_width_cm"].std()
# Out:
# 0.197752680004544

# %%
df.loc[:,"petal_length_cm"].var()
# Out:
# 0.22081632653061237

# %%
df.loc[:,"petal_width_cm"].var()
# Out:
# 0.039106122448979576

# %%
_=plt.scatter(df['petal_length_cm'], df['petal_width_cm'])
_=plt.xlabel('petal length')
_=plt.ylabel('petal width')
plt.show()

# %%
#comment
Note that the higher the length of the petal, the greater the width of the petal, and the seedlings that ranged in length from
4cm to 4.5cm have a fixed width is 1.3cm.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
df_swing = pd.read_csv('2008_swing_states.csv')

# %%
df_swing
# Out:
#       year state                                       county   fips  \
# 0     2008    AL                               Autauga County   1001
# 1     2008    AL                               Baldwin County   1003
# 2     2008    AL                               Barbour County   1005
# 3     2008    AL                                  Bibb County   1007
# 4     2008    AL                                Blount County   1009
# 5     2008    AL                               Bullock County   1011
# 6     2008    AL                                Butler County   1013
# 7     2008    AL                               Calhoun County   1015
# 8     2008    AL                              Chambers County   1017
# 9     2008    AL                              Cherokee County   1019
# 10    2008    AL                               Chilton County   1021
# 11    2008    AL                               Choctaw County   1023
# 12    2008    AL                                Clarke County   1025
# ...

# %%
df_swing[['state','county','pct_dem']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3b3ef85c31a2> in <module>
# ----> 1 df[['state','county','pct_dem']]
#
# NameError: name 'df' is not defined

# %%
df_states=df_swing[df_swing.state == 'AL']
df_states.append(df_swing[df_swing.state == 'DC'])
df_states.append(df_swing[df_swing.state == 'CA'])
# Out:
#      year state                  county  fips  vote_rep  vote_dem  vote_oth  \
# 0    2008    AL          Autauga County  1001     17403      6093       145
# 1    2008    AL          Baldwin County  1003     61271     19386       756
# 2    2008    AL          Barbour County  1005      5866      5697        67
# 3    2008    AL             Bibb County  1007      6262      2299        83
# 4    2008    AL           Blount County  1009     20389      3522       356
# 5    2008    AL          Bullock County  1011      1391      4011        13
# 6    2008    AL           Butler County  1013      5485      4188        36
# 7    2008    AL          Calhoun County  1015     32348     16334       560
# 8    2008    AL         Chambers County  1017      8067      6799        90
# 9    2008    AL         Cherokee County  1019      7298      2306       141
# 10   2008    AL          Chilton County  1021     13960      3674       151
# ...

# %%
bin_edges = [0,20,30,40,50,60,70,80,90,100]
_=plt.hist(df_swing['pct_dem'], bins = bin_edges)
_=plt.xlabel('votes for obama')
_=plt.ylabel('number of counties')
plt.show()

# %%
df_Avg=df_swing[(df_swing['pct_dem']>40) & (df_swing['pct_dem']<50)]
df_Avg
# Out:
#       year state                                       county   fips  \
# 2     2008    AL                               Barbour County   1005
# 6     2008    AL                                Butler County   1013
# 8     2008    AL                              Chambers County   1017
# 11    2008    AL                               Choctaw County   1023
# 12    2008    AL                                Clarke County   1025
# 17    2008    AL                               Conecuh County   1035
# 18    2008    AL                                 Coosa County   1037
# 44    2008    AL                               Madison County   1089
# 48    2008    AL                                Mobile County   1097
# 49    2008    AL                                Monroe County   1099
# 53    2008    AL                               Pickens County   1107
# 54    2008    AL                                  Pike County   1109
# 60    2008    AL                             Talladega County   1121
# ...

# %%
df_Avg["state"].value_counts()
# Out:
# IN    52
# MN    49
# VA    48
# IA    46
# IL    44
# MI    40
# MO    35
# OH    34
# KY    33
# NC    32
# GA    29
# PA    27
# NY    26
# SD    24
# WV    23
# FL    21
# MS    19
# CA    19
# SC    17
# TX    16
# TN    16
# LA    14
# WI    14
# AL    14
# AK    12
# MD    12
# CO    12
# KS    11
# ND    11
# MT    11
# WA    10
# OR    10
# AR     9
# NE     8
# NV     6
# NJ     6
# OK     6
# ID     6
# AZ     4
# UT     3
# NM     3
# ME     2
# DE     1
# Name: state, dtype: int64

# %%
df_MAX = df_Avg[df_Avg.state == 'IN']
df_MAX = df_MAX.append(df_Avg[df_Avg.state == 'MN'])
df_MAX = df_MAX.append(df_Avg[df_Avg.state == 'VA'])

df_MAX['state']
# Out:
# 669     IN
# 670     IN
# 671     IN
# 672     IN
# 674     IN
# 675     IN
# 676     IN
# 677     IN
# 678     IN
# 679     IN
# 680     IN
# 684     IN
# 686     IN
# 687     IN
# 688     IN
# 689     IN
# 690     IN
# 692     IN
# 693     IN
# 694     IN
# 695     IN
# 698     IN
# 700     IN
# 701     IN
# 703     IN
# 705     IN
# 706     IN
# 707     IN
# 709     IN
# 717     IN
#         ..
# 2836    VA
# 2837    VA
# 2839    VA
# 2841    VA
# 2844    VA
# 2845    VA
# 2846    VA
# 2848    VA
# 2854    VA
# 2855    VA
# 2856    VA
# 2857    VA
# 2862    VA
# 2865    VA
# 2866    VA
# 2868    VA
# 2870    VA
# 2874    VA
# 2875    VA
# 2876    VA
# 2880    VA
# 2885    VA
# 2887    VA
# 2889    VA
# 2900    VA
# 2905    VA
# 2911    VA
# 2918    VA
# 2921    VA
# 2922    VA
# Name: state, Length: 149, dtype: object

# %%
_= sns.swarmplot(x='state',y='pct_dem', data=df_MAX)
_=plt.xlabel('states')
_=plt.ylabel('percentage of vote for obama')
plt.show()
